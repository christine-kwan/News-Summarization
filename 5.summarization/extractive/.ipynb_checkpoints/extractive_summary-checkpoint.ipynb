# %% [markdown]
# ### TextRank Extractive Summarization method

# %%
import pandas as pd

# import nltk
# from nltk.tokenize import sent_tokenize, word_tokenize
# from nltk.corpus import stopwords
# from nltk.probability import FreqDist
# from nltk.stem import PorterStemmer
# from nltk.tokenize import word_tokenize, sent_tokenize
# from collections import defaultdict

# %%
# df = pd.read_csv("../cleaned_data/cna_cleaned_with_NER.csv")
# content = df[["url", "cleaned_content"]]

# %%
# from summarizer import summarize

# title = "Sports"

# url = []
# s = []

# for index, row in content.iterrows():
#     url.append(row["url"])
#     summary = summarize(title, row['cleaned_content'])
#     s.append(summary)


# df = pd.DataFrame(list(zip(url, s)), columns =['url', 'summarised_content'])

# df.to_csv("cna_extractive_summary.csv")

# %%
# evaluate model =acc etc 
# rouge technique
# find the best technique
# golden truth , put into hugging face, chatgpt

# %%
import pandas as pd
import numpy as np
import spacy
from sentence_transformers import SentenceTransformer
from datetime import datetime as dt


### Helper function

def text_to_sent_list(text, 
                      nlp = spacy.load("en_core_web_lg"), 
                      embedder = SentenceTransformer('distilbert-base-nli-mean-tokens'),
                      min_len=2):
    
    ''' Returns cleaned article sentences and BERT sentence embeddings'''
    
    #convert to list of sentences
    text = nlp(text)
    sents = list(text.sents)
    #remove short sentences by threshhold                                                                                                
    sents_clean = [sentence.text for sentence in sents if len(sentence)> min_len]
    #remove entries with empty list
    sents_clean = [sentence for sentence in sents_clean if len(sentence)!=0]
    #embed sentences (deafult uses BERT SentenceTransformer)
    sents_embedding= np.array(embedder.encode(sents_clean, convert_to_tensor=True))
    
    return sents_clean, sents_embedding



### Script

# output_file = 'train_stats_df_processed_extr_5000.pickle'  
#load full extractive df
df = pd.read_csv("../cleaned_data/cna_cleaned_with_NER.csv")
content = df["cleaned_content"]

#truncate for local computation
# df= df.head(5000).reset_index(drop=True)

#load nlp and embedder
nlp = spacy.load("en_core_web_lg")
embedder = SentenceTransformer('distilbert-base-nli-mean-tokens')

t1 = dt.now()
print(t1)

#extract clean sentence list and sentence embedding for each article TEXT
f = lambda text: text_to_sent_list(text, nlp=nlp, embedder=embedder, min_len=2)
s_interim_tuple = content.apply(f)

content['text_clean'] = s_interim_tuple.apply(lambda x: x[0])
content['text_embedding'] = s_interim_tuple.apply(lambda x: x[1])

#extract clean sentence list and sentence embedding for each article SUMMARY
f = lambda summ: text_to_sent_list(summ, nlp=nlp, embedder=embedder, min_len=0)
s_interim_tuple = content['summary'].apply(f)

content['summary_clean'] = s_interim_tuple.apply(lambda x: x[0])
content['summary_embedding'] = s_interim_tuple.apply(lambda x: x[1])

# with open(output_file, 'wb') as handle:                                     
#     pickle.dump(df, handle)

t2=dt.now()
print(t2)
print(t2-t1)

content.head(10)

#5000 articles took 1hr40mins

# %%
conda install -c conda-forge spacy
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/christine/anaconda3
#
#   added / updated specs:
#     - spacy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     boltons-23.0.0             |     pyhd8ed1ab_0         296 KB  conda-forge
#     ca-certificates-2022.12.7  |       h033912b_0         142 KB  conda-forge
#     catalogue-2.0.8            |  py310h2ec42d9_1          32 KB  conda-forge
#     certifi-2022.12.7          |     pyhd8ed1ab_0         147 KB  conda-forge
#     commonmark-0.9.1           |             py_0          46 KB  conda-forge
#     conda-23.3.0               |  py310hecd8cb5_0         974 KB
#     confection-0.0.4           |  py310ha188af9_1          62 KB  conda-forge
#     cymem-2.0.7                |  py310h7a76584_1          34 KB  conda-forge
#     cython-blis-0.7.9          |  py310h936d966_1         5.6 MB  conda-forge
#     dataclasses-0.8            |     pyhc8e2a94_3          10 KB  conda-forge
#     langcodes-3.3.0            |     pyhd8ed1ab_0         156 KB  conda-forge
#     murmurhash-1.0.9           |  py310h7a76584_1          23 KB  conda-forge
#     openssl-1.1.1t             |       hfd90126_0         1.7 MB  conda-forge
#     pathy-0.10.1               |     pyhd8ed1ab_0          42 KB  conda-forge
#     preshed-3.0.8              |  py310h7a76584_1          92 KB  conda-forge
#     pydantic-1.10.7            |  py310h90acd4f_0         1.8 MB  conda-forge
#     python_abi-3.10            |          2_cp310           4 KB  conda-forge
#     rich-12.6.0                |     pyhd8ed1ab_0         170 KB  conda-forge
#     shellingham-1.5.1          |     pyhd8ed1ab_0          14 KB  conda-forge
#     spacy-3.5.1                |  py310h3e792ce_0         4.6 MB  conda-forge
#     spacy-legacy-3.0.12        |     pyhd8ed1ab_0          28 KB  conda-forge
#     spacy-loggers-1.0.4        |     pyhd8ed1ab_0          15 KB  conda-forge
#     srsly-2.4.6                |  py310h7a76584_0         540 KB  conda-forge
#     thinc-8.1.9                |  py310h3e792ce_0         745 KB  conda-forge
#     typer-0.7.0                |     pyhd8ed1ab_0          56 KB  conda-forge
#     wasabi-1.1.1               |  py310h2ec42d9_1          47 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        17.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   boltons            conda-forge/noarch::boltons-23.0.0-pyhd8ed1ab_0
#   catalogue          conda-forge/osx-64::catalogue-2.0.8-py310h2ec42d9_1
#   commonmark         conda-forge/noarch::commonmark-0.9.1-py_0
#   confection         conda-forge/osx-64::confection-0.0.4-py310ha188af9_1
#   cymem              conda-forge/osx-64::cymem-2.0.7-py310h7a76584_1
#   cython-blis        conda-forge/osx-64::cython-blis-0.7.9-py310h936d966_1
#   dataclasses        conda-forge/noarch::dataclasses-0.8-pyhc8e2a94_3
#   langcodes          conda-forge/noarch::langcodes-3.3.0-pyhd8ed1ab_0
#   murmurhash         conda-forge/osx-64::murmurhash-1.0.9-py310h7a76584_1
#   pathy              conda-forge/noarch::pathy-0.10.1-pyhd8ed1ab_0
#   preshed            conda-forge/osx-64::preshed-3.0.8-py310h7a76584_1
#   pydantic           conda-forge/osx-64::pydantic-1.10.7-py310h90acd4f_0
#   python_abi         conda-forge/osx-64::python_abi-3.10-2_cp310
#   rich               conda-forge/noarch::rich-12.6.0-pyhd8ed1ab_0
#   shellingham        conda-forge/noarch::shellingham-1.5.1-pyhd8ed1ab_0
#   spacy              conda-forge/osx-64::spacy-3.5.1-py310h3e792ce_0
#   spacy-legacy       conda-forge/noarch::spacy-legacy-3.0.12-pyhd8ed1ab_0
#   spacy-loggers      conda-forge/noarch::spacy-loggers-1.0.4-pyhd8ed1ab_0
#   srsly              conda-forge/osx-64::srsly-2.4.6-py310h7a76584_0
#   thinc              conda-forge/osx-64::thinc-8.1.9-py310h3e792ce_0
#   typer              conda-forge/noarch::typer-0.7.0-pyhd8ed1ab_0
#   wasabi             conda-forge/osx-64::wasabi-1.1.1-py310h2ec42d9_1
#
# The following packages will be UPDATED:
#
#   conda                              23.1.0-py310hecd8cb5_0 --> 23.3.0-py310hecd8cb5_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    pkgs/main::ca-certificates-2023.01.10~ --> conda-forge::ca-certificates-2022.12.7-h033912b_0
#   certifi            pkgs/main/osx-64::certifi-2022.12.7-p~ --> conda-forge/noarch::certifi-2022.12.7-pyhd8ed1ab_0
#   openssl              pkgs/main::openssl-1.1.1t-hca72f7f_0 --> conda-forge::openssl-1.1.1t-hfd90126_0
#
#
#
# Downloading and Extracting Packages
# murmurhash-1.0.9     | 23 KB     |                                       |   0%
# preshed-3.0.8        | 92 KB     |                                       |   0%
#
# srsly-2.4.6          | 540 KB    |                                       |   0%
#
#
# wasabi-1.1.1         | 47 KB     |                                       |   0%
#
#
#
# cymem-2.0.7          | 34 KB     |                                       |   0%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    |                                       |   0%
#
#
#
#
#
# thinc-8.1.9          | 745 KB    |                                       |   0%
#
#
#
#
#
#
# spacy-legacy-3.0.12  | 28 KB     |                                       |   0%
#
#
#
#
#
#
#
# pathy-0.10.1         | 42 KB     |                                       |   0%
#
#
#
#
#
#
#
#
# spacy-loggers-1.0.4  | 15 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
# langcodes-3.3.0      | 156 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# confection-0.0.4     | 62 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# boltons-23.0.0       | 296 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# typer-0.7.0          | 56 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# rich-12.6.0          | 170 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# shellingham-1.5.1    | 14 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1t       | 1.7 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-blis-0.7.9    | 5.6 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# catalogue-2.0.8      | 32 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python_abi-3.10      | 4 KB      |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# commonmark-0.9.1     | 46 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# dataclasses-0.8      | 10 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2022.12.7    | 147 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# preshed-3.0.8        | 92 KB     | ######4                               |  17%
#
#
#
# murmurhash-1.0.9     | 23 KB     | #########################2            |  68%
#
#
# wasabi-1.1.1         | 47 KB     | ############7                         |  34%
#
# srsly-2.4.6          | 540 KB    | #                                     |   3%
# preshed-3.0.8        | 92 KB     | ################################2     |  87%
#
#
#
# murmurhash-1.0.9     | 23 KB     | ##################################### | 100%
#
#
# wasabi-1.1.1         | 47 KB     | ##################################### | 100%
# preshed-3.0.8        | 92 KB     | ##################################### | 100%
# pathy-0.10.1         | 42 KB     | ##############1                       |  38%
#
# srsly-2.4.6          | 540 KB    | ##########9                           |  30%
#
#
#
#
#
#
# spacy-legacy-3.0.12  | 28 KB     | #####################1                |  57%
#
#
#
#
#
#
#
# pathy-0.10.1         | 42 KB     | ##################################### | 100%
#
#
#
#
#
#
# spacy-legacy-3.0.12  | 28 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
# spacy-loggers-1.0.4  | 15 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# langcodes-3.3.0      | 156 KB    | ###7                                  |  10%
#
#
#
#
#
#
#
#
# spacy-loggers-1.0.4  | 15 KB     | ##################################### | 100%
#
# srsly-2.4.6          | 540 KB    | ###################7                  |  53%
#
#
#
#
#
#
#
#
#
# langcodes-3.3.0      | 156 KB    | ##################################1   |  92%
#
# srsly-2.4.6          | 540 KB    | ############################4         |  77%
#
#
#
#
#
#
#
#
#
# langcodes-3.3.0      | 156 KB    | ##################################### | 100%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | 1                                     |   0%
#
#
#
#
#
#
#
#
#
#
#
# boltons-23.0.0       | 296 KB    | ##                                    |   5%
#
#
#
#
#
# thinc-8.1.9          | 745 KB    | 7                                     |   2%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | 6                                     |   2%
#
# srsly-2.4.6          | 540 KB    | ##################################### | 100%
#
# srsly-2.4.6          | 540 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# boltons-23.0.0       | 296 KB    | ############################          |  76%
#
#
#
#
#
# thinc-8.1.9          | 745 KB    | ###1                                  |   9%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | 8                                     |   2%
#
#
#
#
#
#
#
#
#
#
#
# boltons-23.0.0       | 296 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# confection-0.0.4     | 62 KB     | #########4                            |  26%
#
#
#
#
#
#
#
#
#
#
#
#
#
# rich-12.6.0          | 170 KB    | ###4                                  |   9%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | ##1                                   |   6%
#
#
#
#
#
# thinc-8.1.9          | 745 KB    | #########5                            |  26%
#
#
#
#
#
#
#
#
#
#
# confection-0.0.4     | 62 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# typer-0.7.0          | 56 KB     | ##########5                           |  28%
#
#
#
#
#
#
#
#
#
#
#
#
#
# rich-12.6.0          | 170 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# rich-12.6.0          | 170 KB    | ##################################### | 100%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | ###                                   |   8%
#
#
#
#
#
# thinc-8.1.9          | 745 KB    | ##############3                       |  39%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# shellingham-1.5.1    | 14 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# shellingham-1.5.1    | 14 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1t       | 1.7 MB    | 3                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
# typer-0.7.0          | 56 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# typer-0.7.0          | 56 KB     | ##################################### | 100%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | ####4                                 |  12%
#
#
#
#
#
# thinc-8.1.9          | 745 KB    | #######################               |  62%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1t       | 1.7 MB    | ######6                               |  18%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | #####5                                |  15%
#
#
#
#
#
# thinc-8.1.9          | 745 KB    | #############################4        |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1t       | 1.7 MB    | ##########4                           |  28%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | ######4                               |  17%
#
#
#
#
#
# thinc-8.1.9          | 745 KB    | ##################################9   |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1t       | 1.7 MB    | ##############2                       |  39%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-blis-0.7.9    | 5.6 MB    | 1                                     |   0%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | #######3                              |  20%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1t       | 1.7 MB    | ###################4                  |  53%
#
#
#
#
#
# thinc-8.1.9          | 745 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# catalogue-2.0.8      | 32 KB     | ##################2                   |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-blis-0.7.9    | 5.6 MB    | #1                                    |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# catalogue-2.0.8      | 32 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1t       | 1.7 MB    | #######################6              |  64%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python_abi-3.10      | 4 KB      | ##################################### | 100%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | ########1                             |  22%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python_abi-3.10      | 4 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-blis-0.7.9    | 5.6 MB    | #6                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1t       | 1.7 MB    | ############################1         |  76%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | ########9                             |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# commonmark-0.9.1     | 46 KB     | ############8                         |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# commonmark-0.9.1     | 46 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1t       | 1.7 MB    | ###############################9      |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-blis-0.7.9    | 5.6 MB    | ##4                                   |   7%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | #########6                            |  26%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# dataclasses-0.8      | 10 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1t       | 1.7 MB    | ###################################4  |  96%
# dataclasses-0.8      | 10 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-blis-0.7.9    | 5.6 MB    | ###5                                  |  10%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | ##########3                           |  28%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2022.12.7    | 147 KB    | ####                                  |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1t       | 1.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-blis-0.7.9    | 5.6 MB    | ####3                                 |  12%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | ##########9                           |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2022.12.7    | 147 KB    | ####################                  |  54%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-blis-0.7.9    | 5.6 MB    | #####7                                |  16%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2022.12.7    | 147 KB    | ##################################### | 100%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | ###########7                          |  32%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-blis-0.7.9    | 5.6 MB    | #######5                              |  20%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | ############4                         |  34%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | #############3                        |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-blis-0.7.9    | 5.6 MB    | ########6                             |  23%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | ##############2                       |  38%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-blis-0.7.9    | 5.6 MB    | ##########2                           |  28%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | ##############9                       |  41%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-blis-0.7.9    | 5.6 MB    | ###########4                          |  31%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | ###############7                      |  43%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-blis-0.7.9    | 5.6 MB    | ############8                         |  35%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | ################6                     |  45%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-blis-0.7.9    | 5.6 MB    | ##############                        |  38%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-blis-0.7.9    | 5.6 MB    | ###############3                      |  41%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | #################3                    |  47%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-blis-0.7.9    | 5.6 MB    | ################8                     |  46%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | ##################3                   |  50%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-blis-0.7.9    | 5.6 MB    | ##################2                   |  49%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | ###################1                  |  52%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-blis-0.7.9    | 5.6 MB    | ###################6                  |  53%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-blis-0.7.9    | 5.6 MB    | ####################9                 |  57%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | ###################8                  |  54%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-blis-0.7.9    | 5.6 MB    | ######################2               |  60%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | ####################5                 |  55%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | #####################1                |  57%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-blis-0.7.9    | 5.6 MB    | #######################7              |  64%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-blis-0.7.9    | 5.6 MB    | ########################9             |  68%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | #####################7                |  59%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-blis-0.7.9    | 5.6 MB    | ##########################2           |  71%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | ######################4               |  61%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-blis-0.7.9    | 5.6 MB    | ###########################4          |  74%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | #######################2              |  63%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-blis-0.7.9    | 5.6 MB    | ############################5         |  77%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | #######################9              |  65%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-blis-0.7.9    | 5.6 MB    | #############################8        |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-blis-0.7.9    | 5.6 MB    | ###############################3      |  85%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | ########################6             |  67%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-blis-0.7.9    | 5.6 MB    | ################################5     |  88%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | #########################4            |  69%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-blis-0.7.9    | 5.6 MB    | #################################8    |  91%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | ##########################            |  70%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-blis-0.7.9    | 5.6 MB    | ##################################9   |  94%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | ##########################8           |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-blis-0.7.9    | 5.6 MB    | ####################################1 |  98%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | ###########################4          |  74%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | ############################4         |  77%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | #############################2        |  79%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | #############################9        |  81%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | ###############################1      |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cython-blis-0.7.9    | 5.6 MB    | ##################################### | 100%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | ################################2     |  87%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | ################################9     |  89%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | ##################################1   |  92%
# spacy-3.5.1          | 4.6 MB    | ###################################2  |  95%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | ####################################5 |  99%
#
#
#
#
# spacy-3.5.1          | 4.6 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
